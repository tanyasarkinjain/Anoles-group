# %%
import cv2
import numpy as np
from datascience import *
import matplotlib as mpl
from matplotlib import pyplot as plt
import sys
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 120
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
import pandas as pd
import statistics
import image_slicer
import seaborn as sns
from matplotlib.pyplot import figure

# %%
df = pd.read_csv (r'Scale_Data_all.csv')
df = df.drop(columns = ['Average', 'Count Stander dev.'], axis = 1)
df['Quality:(1:best,3:worst)']
# Out:
# 0     3
# 1     3
# 2     1
# 3     1
# 4     2
# 5     1
# 6     3
# 7     2
# 8     3
# 9     1
# 10    2
# 11    3
# 12    3
# 13    2
# 14    2
# 15    1
# 16    2
# 17    3
# 18    3
# 19    3
# 20    2
# 21    2
# 22    2
# 23    3
# 24    2
# 25    1
# 26    1
# 27    1
# 28    1
# 29    1
# 30    3
# 31    3
# 32    1
# 33    1
# 34    1
# 35    1
# 36    2
# 37    1
# 38    1
# 39    1
# 40    1
# 41    1
# 42    1
# 43    1
# 44    1
# Name: Quality:(1:best,3:worst), dtype: int64

# %%
display(df[df['Quality:(1:best,3:worst)'] == '2'])
# Out:
# Empty DataFrame
# Columns: [Guanica County, Tanya Count, Comp count, % dif, Notes, Quality:(1:best,3:worst), Maggie Count, Charlie Count]
# Index: []

# %%
#this function constructs a table for configuring a graph where entries include only those of the indicated quality
def contstruct__tbl(df, quality):
    #entries for a specific name
    temp = df[df['Quality:(1:best,3:worst)'] == quality].loc[:, ['Guanica County','Tanya Count', 'Maggie Count', 'Charlie Count', 'Comp count']] 
    print('displayed')
    return temp



print('Average absolute percent difference', np.mean(abs(df[df['Quality:(1:best,3:worst)'] == 1]['% dif'])))
df1 = contstruct__tbl(df, 1)
df1 = df1.melt(id_vars = ['Guanica County'], value_vars = ['Tanya Count', 'Maggie Count', 'Charlie Count', 'Comp count'])

pd.set_option("display.max_rows", None, "display.max_columns", None)
display(df1)

sns.barplot(hue = 'variable', data = df1, x = 'Guanica County', y = 'value')
# Out:
# Average absolute percent difference 0.0728752990009091
# displayed
#                    Guanica County       variable  value
# 0     117702Ventral-NoFlash-1.png    Tanya Count   42.0
# 1     117702Ventral-NoFlash-2.png    Tanya Count   27.0
# 2     117702Ventral-NoFlash-4.png    Tanya Count   25.0
# 3     117704Ventral-NoFlash-2.png    Tanya Count   35.0
# 4     117716Ventral-NoFlash-4.png    Tanya Count   30.0
# 5      135182Dorsal-NoFlash-2.png    Tanya Count  132.0
# 6      135182Dorsal-NoFlash-3.png    Tanya Count   72.0
# 7     135182Ventral-NoFlash-1.png    Tanya Count   38.0
# 8     135182Ventral-NoFlash-2.png    Tanya Count   39.0
# 9     135182Ventral-NoFlash-3.png    Tanya Count   30.0
# 10    135185Ventral-NoFlash-1.png    Tanya Count   37.0
# 11  135185Ventral-NoFlash-2.png\n    Tanya Count   30.0
# 12    135185Ventral-NoFlash-3.png    Tanya Count   38.0
# 13     135193Dorsal-NoFlash-1.png    Tanya Count   70.0
# 14     135193Dorsal-NoFlash-3.png    Tanya Count   80.0
# 15    135193Ventral-NoFlash-1.png    Tanya Count   44.0
# 16    135193Ventral-NoFlash-2.png    Tanya Count   36.0
# 64    135196Ventral-NoFlash-2.png  Charlie Count   45.0
# 65    135196Ventral-NoFlash-3.png  Charlie Count   46.0
# 66    117702Ventral-NoFlash-1.png     Comp count   40.0
# 67    117702Ventral-NoFlash-2.png     Comp count   29.0
# 68    117702Ventral-NoFlash-4.png     Comp count   20.0
# 69    117704Ventral-NoFlash-2.png     Comp count   33.0
# 70    117716Ventral-NoFlash-4.png     Comp count   33.0
# 71     135182Dorsal-NoFlash-2.png     Comp count  141.0
# 72     135182Dorsal-NoFlash-3.png     Comp count   78.0
# 73    135182Ventral-NoFlash-1.png     Comp count   36.0
# 74    135182Ventral-NoFlash-2.png     Comp count   38.0
# 75    135182Ventral-NoFlash-3.png     Comp count   30.0
# 76    135185Ventral-NoFlash-1.png     Comp count   36.0
# 77  135185Ventral-NoFlash-2.png\n     Comp count   23.0
# 78    135185Ventral-NoFlash-3.png     Comp count   36.0
# 79     135193Dorsal-NoFlash-1.png     Comp count   79.0
# 80     135193Dorsal-NoFlash-3.png     Comp count   80.0
# 81    135193Ventral-NoFlash-1.png     Comp count   44.0
# 82    135193Ventral-NoFlash-2.png     Comp count   33.0
# 83    135193Ventral-NoFlash-3.png     Comp count   42.0
# 84    135193Ventral-NoFlash-4.png     Comp count   34.0
# 85    135196Ventral-NoFlash-1.png     Comp count   56.0
# 86    135196Ventral-NoFlash-2.png     Comp count   45.0
# 87    135196Ventral-NoFlash-3.png     Comp count   46.0
# <AxesSubplot:xlabel='Guanica County', ylabel='value'>

# %%
#this function constructs a table for configuring a graph where entries include only those of the indicated quality
def contstruct_tbl(df, quality, name):
    #entries for a specific name
    display(df[df['Quality:(1:best,3:worst)'] == quality])
    temp = df[df['Quality:(1:best,3:worst)'] == quality].loc[:, ['Guanica County', name + ' Count']] 
    temp['count type'] = [name +'handcount' for i in np.arange(len(temp))]
    temp = temp.rename(columns = {name + ' Count':'count'})
    print('displayed')
    
    #automated entries
    temp2 = df[df['Quality:(1:best,3:worst)'] == quality].loc[:, ['Guanica County', 'Comp count']] 
    temp2 = temp2.rename(columns = {'Comp count':'count'})
    temp2['count type'] = ['automated' for i in np.arange(len(temp2))]

    return pd.concat([temp, temp2])



print('Average absolute percent difference', np.mean(abs(df[df['Quality:(1:best,3:worst)'] == 1]['% dif'])))




figure(figsize=(30, 30), dpi=80)
df1 = contstruct_tbl(df, 1,'Tanya')
sns.barplot(x='Guanica County', y = 'count', data = df1, hue = 'count type')
plt.title('handcount vs automated for best quality original images (1)')
plt.xlabel('image')
plt.ylabel('count')

# #calculate regression??
# grouped = df1.sort_values(by = ['Tanya Count'])
# display(grouped)
# grouped = grouped.groupby(['Guanica County']).agg(list)
# display(grouped)
# sns.lmplot([i[0] for i in count])
# Out:
# Average absolute percent difference 0.0728752990009091
#                    Guanica County  Tanya Count  Comp count     % dif  \
# 0      117702Dorsal-NoFlash-1.png           74          50 -0.387097
# 1      117702Dorsal-NoFlash-2.png           76          52 -0.375000
# 2     117702Ventral-NoFlash-1.png           42          40 -0.048780
# 10  Difficult to count by hand. Rough small scales...
# 11  Merging. Tiny rough scales difficult to count ...
# 12  Harsh lighting. Lighting illuminates scales fr...
# 13                                    Harsh lighting.
# 14  Unclear/fuzzy in some places. Flash used but n...
# 15                 Very good image, though a bit dark
# 16  Rough scales and harsh lighting in some region...
# 17          Harsh lighting: uneven. Edges illuminated
# 18  Small and not clearly defined. Merging sclaes....
# 19  Scales are not clearly defined. Inverted in so...
# 20  A bit dark in some areas and very bright for s...
# 21                                 Harsh illumination
# 22                        Some harsh lighting lines.
# 23                                      Hash lighting
# 24                         Some merging scales. rough
# 25  Very good image. Clearly defined scales even t...
# 26                                    Very good image
# 27                                    Very good image
# 28                                    Very good image
# 29                                    Very good image
# 30          "inverted" Scales are not clearly defined
# 31  Uneven lighting. "inverted" in some places.  M...
# 32                                    Very good image
# 33                                    Very good image
# 34                                    Very good image
# 35   Good image. Some even bright spots and roughness
# 36    Some scales hard to identify: merging and rough
# 37                                    Very good image
# 38                                    Very good image
# 39                                    Very good image
# 40                                    Very good image
# 41                                    Very good image
# 42                                    Very good image
# 43                                    Very good image
# 44       Very good image except in lower right corner
#
#     Quality:(1:best,3:worst)  Maggie Hand Count  Charlie Hand Count
# 0                          3                 82                78.0
# 1                          3                 87                81.0
# 2                          1                 44                40.0
# 3                          1                 27                25.0
# 4                          2                 32                30.0
# 5                          1                 24                21.0
# 6                          3                 83                 NaN
# 7                          2                148                 NaN
# 8                          3                 23                20.0
# 9                          1                 38                33.0
# 10                         2                135               142.0
# 11                         3                162               128.0
# 12                         3                 35                28.0
# 13                         2                 52                52.0
# 14                         2                 27                28.0
# 15                         1                 36                32.0
# 16                         2                 47                41.0
# 17                         3                 36                36.0
# 18                         3                184               151.0
# 19                         3                117               111.0
# 20                         2                 88                91.0
# 21                         2                 38                39.0
# 22                         2                 34                34.0
# 23                         3                 42                41.0
# 24                         2                140               145.0
# 25                         1                134               131.0
# 26                         1                 84                88.0
# 27                         1                 37                36.0
# 28                         1                 40                38.0
# 29                         1                 33                32.0
# 30                         3                 95                90.0
# 31                         3                108               105.0
# 32                         1                 42                43.0
# 33                         1                 31                29.0
# 34                         1                 40                38.0
# 35                         1                 82                79.0
# 36                         2                 88                87.0
# 37                         1                 82                80.0
# 38                         1                 50                47.0
# 39                         1                 38                36.0
# 40                         1                 46                45.0
# 41                         1                 37                36.0
# 42                         1                 54                53.0
# 43                         1                 49                45.0
# 44                         1                 50                46.0
#                    Guanica County  Tanya Count  Comp count     % dif  \
# 2     117702Ventral-NoFlash-1.png           42          40 -0.048780
# 3     117702Ventral-NoFlash-2.png           27          29  0.071429
# 5     117702Ventral-NoFlash-4.png           25          20 -0.222222
# 9     117704Ventral-NoFlash-2.png           35          33 -0.058824
# 15    117716Ventral-NoFlash-4.png           30          33  0.095238
# 25     135182Dorsal-NoFlash-2.png          132         141  0.065934
# 26     135182Dorsal-NoFlash-3.png           72          78  0.080000
# 27    135182Ventral-NoFlash-1.png           38          36 -0.054054
# 28    135182Ventral-NoFlash-2.png           39          38 -0.025974
# 29    135182Ventral-NoFlash-3.png           30          30  0.000000
# 32    135185Ventral-NoFlash-1.png           37          36 -0.027397
# 33  135185Ventral-NoFlash-2.png\n           30          23 -0.264151
# 34    135185Ventral-NoFlash-3.png           38          36 -0.054054
# 35     135193Dorsal-NoFlash-1.png           70          79  0.120805
# 37     135193Dorsal-NoFlash-3.png           80          80  0.000000
# 38    135193Ventral-NoFlash-1.png           44          44  0.000000
# 39    135193Ventral-NoFlash-2.png           36          33 -0.086957
# 40    135193Ventral-NoFlash-3.png           46          42 -0.090909
# 41    135193Ventral-NoFlash-4.png           36          34 -0.057143
# 42    135196Ventral-NoFlash-1.png           52          56  0.074074
# 43    135196Ventral-NoFlash-2.png           46          45 -0.021978
# 44    135196Ventral-NoFlash-3.png           50          46 -0.083333
#
#                                                 Notes  \
# 2         Good image: uneven size but good seperation
# 3   Harsh lighting but scales not illuminated in m...
# 5          Good seperation. Some dark spots on scales
# 9                                     Very good image
# 15                 Very good image, though a bit dark
# 25  Very good image. Clearly defined scales even t...
# 26                                    Very good image
# 27                                    Very good image
# 28                                    Very good image
# 29                                    Very good image
# 32                                    Very good image
# 33                                    Very good image
# 34                                    Very good image
# 35   Good image. Some even bright spots and roughness
# 37                                    Very good image
# 38                                    Very good image
# 39                                    Very good image
# 40                                    Very good image
# 41                                    Very good image
# 42                                    Very good image
# 43                                    Very good image
# 44       Very good image except in lower right corner
#
#     Quality:(1:best,3:worst)  Maggie Hand Count  Charlie Hand Count
# 2                          1                 44                40.0
# 3                          1                 27                25.0
# 5                          1                 24                21.0
# 9                          1                 38                33.0
# 15                         1                 36                32.0
# 25                         1                134               131.0
# 26                         1                 84                88.0
# 27                         1                 37                36.0
# 28                         1                 40                38.0
# 29                         1                 33                32.0
# 32                         1                 42                43.0
# 33                         1                 31                29.0
# 34                         1                 40                38.0
# 35                         1                 82                79.0
# 37                         1                 82                80.0
# 38                         1                 50                47.0
# 39                         1                 38                36.0
# 40                         1                 46                45.0
# 41                         1                 37                36.0
# 42                         1                 54                53.0
# 43                         1                 49                45.0
# 44                         1                 50                46.0
#                    Guanica County  Tanya Count
# 2     117702Ventral-NoFlash-1.png           42
# 3     117702Ventral-NoFlash-2.png           27
# 5     117702Ventral-NoFlash-4.png           25
# 9     117704Ventral-NoFlash-2.png           35
# 15    117716Ventral-NoFlash-4.png           30
# 25     135182Dorsal-NoFlash-2.png          132
# 26     135182Dorsal-NoFlash-3.png           72
# 27    135182Ventral-NoFlash-1.png           38
# 28    135182Ventral-NoFlash-2.png           39
# 29    135182Ventral-NoFlash-3.png           30
# 32    135185Ventral-NoFlash-1.png           37
# 33  135185Ventral-NoFlash-2.png\n           30
# 34    135185Ventral-NoFlash-3.png           38
# 35     135193Dorsal-NoFlash-1.png           70
# 37     135193Dorsal-NoFlash-3.png           80
# 38    135193Ventral-NoFlash-1.png           44
# 39    135193Ventral-NoFlash-2.png           36
# 40    135193Ventral-NoFlash-3.png           46
# 41    135193Ventral-NoFlash-4.png           36
# 42    135196Ventral-NoFlash-1.png           52
# 43    135196Ventral-NoFlash-2.png           46
# 44    135196Ventral-NoFlash-3.png           50
# displayed
#                    Guanica County  count      count type
# 2     117702Ventral-NoFlash-1.png     42  Tanyahandcount
# 3     117702Ventral-NoFlash-2.png     27  Tanyahandcount
# 5     117702Ventral-NoFlash-4.png     25  Tanyahandcount
# 9     117704Ventral-NoFlash-2.png     35  Tanyahandcount
# 15    117716Ventral-NoFlash-4.png     30  Tanyahandcount
# 25     135182Dorsal-NoFlash-2.png    132  Tanyahandcount
# 26     135182Dorsal-NoFlash-3.png     72  Tanyahandcount
# 27    135182Ventral-NoFlash-1.png     38  Tanyahandcount
# 28    135182Ventral-NoFlash-2.png     39  Tanyahandcount
# 29    135182Ventral-NoFlash-3.png     30  Tanyahandcount
# 32    135185Ventral-NoFlash-1.png     37  Tanyahandcount
# 33  135185Ventral-NoFlash-2.png\n     30  Tanyahandcount
# 34    135185Ventral-NoFlash-3.png     38  Tanyahandcount
# 35     135193Dorsal-NoFlash-1.png     70  Tanyahandcount
# 37     135193Dorsal-NoFlash-3.png     80  Tanyahandcount
# 38    135193Ventral-NoFlash-1.png     44  Tanyahandcount
# 39    135193Ventral-NoFlash-2.png     36  Tanyahandcount
# 40    135193Ventral-NoFlash-3.png     46  Tanyahandcount
# 41    135193Ventral-NoFlash-4.png     36  Tanyahandcount
# 42    135196Ventral-NoFlash-1.png     52  Tanyahandcount
# 43    135196Ventral-NoFlash-2.png     46  Tanyahandcount
# 44    135196Ventral-NoFlash-3.png     50  Tanyahandcount
# Text(0, 0.5, 'count')

# %%
df2 = contstruct_tbl(df, 2)
figure(figsize=(10, 10), dpi=80)
print('Average absolute percent difference', np.mean(abs(df[df['Quality:(1:best,3:worst)'] == 2]['% dif'])))
sns.barplot(x='Guanica County', y = 'count', data = df2, hue = 'count type')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-144283009d58> in <module>
# ----> 1 df2 = contstruct_tbl(df, 2)
#       2 figure(figsize=(10, 10), dpi=80)
#       3 print('Average absolute percent difference', np.mean(abs(df[df['Quality:(1:best,3:worst)'] == 2]['% dif'])))
#       4 sns.barplot(x='Guanica County', y = 'count', data = df2, hue = 'count type')
#
# TypeError: contstruct_tbl() missing 1 required positional argument: 'name'

# %%
df3 = contstruct_tbl(df, 3)
print('Average absolute percent difference', np.mean(abs(df[df['Quality:(1:best,3:worst)'] == 3]['% dif'])))
figure(figsize=(10, 10), dpi=80)
sns.barplot(x='Guanica County', y = 'count', data = df3, hue = 'count type')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-efd6c70e836a> in <module>
# ----> 1 df3 = contstruct_tbl(df, 3)
#       2 print('Average absolute percent difference', np.mean(abs(df[df['Quality:(1:best,3:worst)'] == 3]['% dif'])))
#       3 figure(figsize=(10, 10), dpi=80)
#       4 sns.barplot(x='Guanica County', y = 'count', data = df3, hue = 'count type')
#
# TypeError: contstruct_tbl() missing 1 required positional argument: 'name'

# %%
'''How to compare counts statistically?: Possian contingency?'''
